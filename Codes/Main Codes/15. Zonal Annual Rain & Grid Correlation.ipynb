# %%
#Importing all the required libraries
import xarray 
import os
import netCDF4
import numpy as np
import matplotlib.pyplot as plt
import imdlib as imd
import pandas as pd
import scipy.io as sio
import matplotlib.patches as patches
import matplotlib.patches as mpatches

# %%
def PlotSSTMap(data, year=None):
    # Create a figure and axis for the plot
    fig, ax = plt.subplots(figsize=(20, 10))

    # Create a colormap
    cmap = plt.get_cmap('seismic')  # You can choose any other colormap you prefer

    # Determine the appropriate color limits based on your data
    vmin = -1.0  # Minimum value for the color scale
    vmax = 1.0  # Maximum value for the color scale

    # Get the shape of the data
    rows, cols = (89,180)
   
     # Loop through each grid point and add a rectangle
#     for row in range(rows):
#         for col in range(cols):
#             rect = mpatches.Rectangle((col, row), 1, 1, linewidth=1, edgecolor='black', facecolor='None')
#             ax.add_patch(rect)
           
    # Plot the average yearly SST data using the colormap
    im = ax.imshow(data, cmap=cmap, vmin=vmin, vmax=vmax, origin='lower', extent=[0, cols, 0, rows])

    # Add colorbar
    cbar = plt.colorbar(im, ax=ax, label='Temperature')

    # Set axis labels
    ax.set_xlabel('Longitude')
    ax.set_ylabel('Latitude')
    ax.set_title(f'{year} Coorelation with SST')
    
    #plt.savefig(f'{year} Coorelation with SST')
    # Show the plot
    plt.show()

# %%
zone1=pd.read_csv(r"C:\Users\ratho\Desktop\Software Group Project - III\Climate Data Modelling\Our Work\CSV Excel Data\Zone 1 Yearly Mean 1901-2022.csv",index_col=0)
zone2=pd.read_csv(r"C:\Users\ratho\Desktop\Software Group Project - III\Climate Data Modelling\Our Work\CSV Excel Data\Zone 2 Yearly Mean 1901-2022.csv",index_col=0)
zone3=pd.read_csv(r"C:\Users\ratho\Desktop\Software Group Project - III\Climate Data Modelling\Our Work\CSV Excel Data\Zone 3 Yearly Mean 1901-2022.csv",index_col=0)
zone4=pd.read_csv(r"C:\Users\ratho\Desktop\Software Group Project - III\Climate Data Modelling\Our Work\CSV Excel Data\Zone 4 Yearly Mean 1901-2022.csv",index_col=0)
zone5=pd.read_csv(r"C:\Users\ratho\Desktop\Software Group Project - III\Climate Data Modelling\Our Work\CSV Excel Data\Zone 5 Yearly Mean 1901-2022.csv",index_col=0)
zone6=pd.read_csv(r"C:\Users\ratho\Desktop\Software Group Project - III\Climate Data Modelling\Our Work\CSV Excel Data\Zone 6 Yearly Mean 1901-2022.csv",index_col=0)
zone7=pd.read_csv(r"C:\Users\ratho\Desktop\Software Group Project - III\Climate Data Modelling\Our Work\CSV Excel Data\Zone 7 Yearly Mean 1901-2022.csv",index_col=0)
zone8=pd.read_csv(r"C:\Users\ratho\Desktop\Software Group Project - III\Climate Data Modelling\Our Work\CSV Excel Data\Zone 8 Yearly Mean 1901-2022.csv",index_col=0)

sst_grid=pd.read_csv(r"C:\Users\ratho\Desktop\Software Group Project - III\Climate Data Modelling\Our Work\CSV Excel Data\SST Grid Values 1901-2022.csv",index_col=0)

# %%
correlation_coefficients_zone1 = sst_grid.corrwith(zone1.squeeze(), axis=0)
correlation_coefficients_zone2 = sst_grid.corrwith(zone2.squeeze(), axis=0)
correlation_coefficients_zone3 = sst_grid.corrwith(zone3.squeeze(), axis=0)
correlation_coefficients_zone4 = sst_grid.corrwith(zone4.squeeze(), axis=0)
correlation_coefficients_zone5 = sst_grid.corrwith(zone5.squeeze(), axis=0)
correlation_coefficients_zone6 = sst_grid.corrwith(zone6.squeeze(), axis=0)
correlation_coefficients_zone7 = sst_grid.corrwith(zone7.squeeze(), axis=0)
correlation_coefficients_zone8 = sst_grid.corrwith(zone8.squeeze(), axis=0)

# %%
corr_matrix_zone1 = correlation_coefficients_zone1.to_numpy()
corr_matrix_zone1 = corr_matrix_zone1.reshape(89, 180)

corr_matrix_zone2 = correlation_coefficients_zone2.to_numpy()
corr_matrix_zone2 = corr_matrix_zone2.reshape(89, 180)

corr_matrix_zone3 = correlation_coefficients_zone3.to_numpy()
corr_matrix_zone3 = corr_matrix_zone3.reshape(89, 180)

corr_matrix_zone4 = correlation_coefficients_zone4.to_numpy()
corr_matrix_zone4 = corr_matrix_zone4.reshape(89, 180)

corr_matrix_zone5 = correlation_coefficients_zone5.to_numpy()
corr_matrix_zone5 = corr_matrix_zone5.reshape(89, 180)

corr_matrix_zone6 = correlation_coefficients_zone6.to_numpy()
corr_matrix_zone6 = corr_matrix_zone6.reshape(89, 180)

corr_matrix_zone7 = correlation_coefficients_zone7.to_numpy()
corr_matrix_zone7 = corr_matrix_zone7.reshape(89, 180)

corr_matrix_zone8 = correlation_coefficients_zone8.to_numpy()
corr_matrix_zone8 = corr_matrix_zone8.reshape(89, 180)

# %%
PlotSSTMap(corr_matrix_zone1,"Zone 1")
PlotSSTMap(corr_matrix_zone2,"Zone 2")
PlotSSTMap(corr_matrix_zone3,"Zone 3")
PlotSSTMap(corr_matrix_zone4,"Zone 4")
PlotSSTMap(corr_matrix_zone5,"Zone 5")
PlotSSTMap(corr_matrix_zone6,"Zone 6")
PlotSSTMap(corr_matrix_zone7,"Zone 7")
PlotSSTMap(corr_matrix_zone8,"Zone 8")

# %%
print("Max correlation value Zone 1: ",correlation_coefficients_zone1.max())
print("Min correlation value Zone 1 : ",correlation_coefficients_zone1.min())

print("\nMax correlation value Zone 2: ",correlation_coefficients_zone2.max())
print("Min correlation value Zone 2 : ",correlation_coefficients_zone2.min())

print("\nMax correlation value Zone 3: ",correlation_coefficients_zone3.max())
print("Min correlation value Zone 3 : ",correlation_coefficients_zone3.min())

print("\nMax correlation value Zone 4: ",correlation_coefficients_zone4.max())
print("Min correlation value Zone 4 : ",correlation_coefficients_zone4.min())

print("\nMax correlation value Zone 5: ",correlation_coefficients_zone5.max())
print("Min correlation value Zone 5 : ",correlation_coefficients_zone5.min())

print("\nMax correlation value Zone 6: ",correlation_coefficients_zone6.max())
print("Min correlation value Zone 6 : ",correlation_coefficients_zone6.min())

print("\nMax correlation value Zone 7: ",correlation_coefficients_zone7.max())
print("Min correlation value Zone 7 : ",correlation_coefficients_zone7.min())

print("\nMax correlation value Zone 8: ",correlation_coefficients_zone8.max())
print("Min correlation value Zone 8 : ",correlation_coefficients_zone8.min())
# Out:
# Max correlation value Zone 1:  0.3496720931282421
# Min correlation value Zone 1 :  -0.3371423408288303
#
# Max correlation value Zone 2:  0.27649101225620926
# Min correlation value Zone 2 :  -0.40063869583474526
#
# Max correlation value Zone 3:  0.36951292418337706
# Min correlation value Zone 3 :  -0.22475704856600298
#
# Max correlation value Zone 4:  0.389446088679631
# Min correlation value Zone 4 :  -0.2928242896122899
#
# Max correlation value Zone 5:  0.2650065976287975
# Min correlation value Zone 5 :  -0.3005146332808825
#
# Max correlation value Zone 6:  0.3576804069521671
# Min correlation value Zone 6 :  -0.270486438446757
#
# Max correlation value Zone 7:  0.31846164544095046
# Min correlation value Zone 7 :  -0.30566849033645743
#
# Max correlation value Zone 8:  0.4444838606390653
# Min correlation value Zone 8 :  -0.4301725263406669
