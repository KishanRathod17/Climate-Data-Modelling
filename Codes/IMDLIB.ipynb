# %%
import imdlib as imd

start_yr = 2010
end_yr =2010
variable = 'rain'
data = imd.get_data(variable, start_yr, end_yr, fn_format='yearwise')
# Out:
# Downloading: rain for year 2010
# Download Successful !!!

# %%
data.get_xarray()
# Out:
# <xarray.Dataset>
# Dimensions:  (time: 365, lat: 129, lon: 135)
# Coordinates:
#   * lat      (lat) float64 6.5 6.75 7.0 7.25 7.5 ... 37.5 37.75 38.0 38.25 38.5
#   * lon      (lon) float64 66.5 66.75 67.0 67.25 67.5 ... 99.25 99.5 99.75 100.0
#   * time     (time) datetime64[ns] 2010-01-01 2010-01-02 ... 2010-12-31
# Data variables:
#     rain     (time, lat, lon) float64 -999.0 -999.0 -999.0 ... -999.0 -999.0
# Attributes:
#     Conventions:  CF-1.7
#     title:        IMD gridded data
#     source:       https://imdpune.gov.in/
#     history:      2023-08-12 10:19:02.842051 Python
#     references:
#     comment:
#     crs:          epsg:4326

# %%
import matplotlib.pyplot as plt
import pandas as pd
df=pd.read_csv(r"C:\Users\ratho\Desktop\Software Group Project - III\Climate Data Modelling\Our Work\Codes\test.csv")

plt.imshow(df, cmap='hot')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 5
#       2 import pandas as pd
#       3 df=pd.read_csv(r"C:\Users\ratho\Desktop\Software Group Project - III\Climate Data Modelling\Our Work\Codes\test.csv")
# ----> 5 plt.imshow(df, cmap='hot')
#
# File ~\anaconda3\lib\site-packages\matplotlib\pyplot.py:2695, in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, interpolation_stage, filternorm, filterrad, resample, url, data, **kwargs)
#    2689 @_copy_docstring_and_deprecators(Axes.imshow)
#    2690 def imshow(
#    2691         X, cmap=None, norm=None, *, aspect=None, interpolation=None,
#    2692         alpha=None, vmin=None, vmax=None, origin=None, extent=None,
#    2693         interpolation_stage=None, filternorm=True, filterrad=4.0,
#    2694         resample=None, url=None, data=None, **kwargs):
# ...
