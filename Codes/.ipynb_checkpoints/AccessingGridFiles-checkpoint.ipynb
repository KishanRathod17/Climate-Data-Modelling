# %%
import imdlib as imd

# %%
data=[]
for i in range(1901,1951):
    data.append(imd.get_data('rain',i,i,'yearwise'))
# Out:
# Downloading: rain for year 1901
# Download Successful !!!
# Downloading: rain for year 1902
# Download Successful !!!
# Downloading: rain for year 1903
# Download Successful !!!
# Downloading: rain for year 1904
# Download Successful !!!
# Downloading: rain for year 1905
# Download Successful !!!
# Downloading: rain for year 1906
# Download Successful !!!
# Downloading: rain for year 1907
# Download Successful !!!
# Downloading: rain for year 1908
# Download Successful !!!
# Downloading: rain for year 1909
# Download Successful !!!
# Downloading: rain for year 1910
# Download Successful !!!
# Downloading: rain for year 1911
# Download Successful !!!
# Downloading: rain for year 1912
# Download Successful !!!
# Downloading: rain for year 1913
# Download Successful !!!
# Downloading: rain for year 1914
# Download Successful !!!
# Downloading: rain for year 1915
# Download Successful !!!
# Downloading: rain for year 1916
# Download Successful !!!
# Downloading: rain for year 1917
# ...

# %%
data = imd.open_data('rain',1901,1950,fn_format='yearwise')
data.shape
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 data = imd.open_data('rain',1901,1950,fn_format='yearwise')
#       2 data.shape
#
# File ~\anaconda3\lib\site-packages\imdlib\core.py:684, in open_data(var_type, start_yr, end_yr, fn_format, file_dir)
#     675 data = np.array(list(map(lambda x: x, temp)))
#     677 # Added for new url (dated:Oct 10, 2022)
#     678 # Removing first element for rain for new url: https://imdpune.gov.in/lrfindex.php
#     679 # Removing (commented out) as it was no longer needed to remove the first element anymore. (dated: March 31, 2023)
#    (...)
#     682
#     683 # Check consistency of data points
# --> 684 if len(data) != nlen:
#     685     raise Exception("Error in file reading,"
#     686                     "mismatch in size of data-length")
#     688 # Reshape data into a shape of
# ...

# %%
data[49].get_xarray()
# Out:
# <xarray.Dataset>
# Dimensions:  (time: 365, lat: 129, lon: 135)
# Coordinates:
#   * lat      (lat) float64 6.5 6.75 7.0 7.25 7.5 ... 37.5 37.75 38.0 38.25 38.5
#   * lon      (lon) float64 66.5 66.75 67.0 67.25 67.5 ... 99.25 99.5 99.75 100.0
#   * time     (time) datetime64[ns] 1950-01-01 1950-01-02 ... 1950-12-31
# Data variables:
#     rain     (time, lat, lon) float64 -999.0 -999.0 -999.0 ... -999.0 -999.0
# Attributes:
#     Conventions:  CF-1.7
#     title:        IMD gridded data
#     source:       https://imdpune.gov.in/
#     history:      2023-08-11 16:41:44.029623 Python
#     references:
#     comment:
#     crs:          epsg:4326

# %%
df=imd.open_data(r"C:\Users\ratho\Desktop\Software Group Project - III\Climate Data Modelling\Data\IMD Grid Data\Rainfall_ind1901_rfp25.grd",start_yr=1901,end_yr=1902
        )
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 df=imd.open_data(r"C:\Users\ratho\Desktop\Software Group Project - III\Climate Data Modelling\Data\IMD Grid Data\Rainfall_ind1901_rfp25.grd",start_yr=1901,end_yr=1902
#       2                 )
#
# File ~\anaconda3\lib\site-packages\imdlib\core.py:647, in open_data(var_type, start_yr, end_yr, fn_format, file_dir)
#     645     lon_size_class = lon_size_temp
#     646 else:
# --> 647     raise Exception("Error in variable type declaration."
#     648                     "It must be 'rain'/'tmin'/'tmax'. ")
#     650 # Loop through all the years
#     651 # all_data -> container to store data for all the year
#     652 # all_data.shape = (no_days, len(lon), len(lat))
#     653 all_data = np.empty((no_days, lon_size_class, lat_size_class))
#
# ...

# %%
year=1901
for i in range(0,50):
    data[i].to_netcdf(f'RF25_ind{year}_rfp25.nc')
    year+=1
