# %%
file_path = r"C:\Users\ratho\Desktop\Software Group Project - III\Climate Data Modelling\RIDDHI\new-code\indiaext_bnd.dat"

try:
    with open(file_path, 'r') as file:
        # Read the entire content of the file
        file_contents = file.read()

        # Alternatively, you can read line by line
        # for line in file:
        #     print(line)

        # If you want to read all lines into a list
        # lines = file.readlines()
        
        # Process or print the content as needed
        print(file_contents)
except FileNotFoundError:
    print(f"The file '{file_path}' does not exist.")
except Exception as e:
    print(f"An error occurred: {e}")
# Out:
#      0.7320274E+02     0.3591295E+02
#      0.7317448E+02     0.3591498E+02
#      0.7314746E+02     0.3591350E+02
#      0.7311742E+02     0.3590631E+02
#      0.7306766E+02     0.3588972E+02
#      0.7301756E+02     0.3587863E+02
#      0.7297668E+02     0.3588187E+02
#      0.7288686E+02     0.3590721E+02
#      0.7286640E+02     0.3590881E+02
#      0.7284352E+02     0.3589643E+02
#      0.7281464E+02     0.3587263E+02
#      0.7279834E+02     0.3586339E+02
#      0.7277115E+02     0.3586459E+02
#      0.7272689E+02     0.3586755E+02
#      0.7268542E+02     0.3587895E+02
#      0.7266083E+02     0.3589134E+02
#      0.7263226E+02     0.3591178E+02
#      0.7260844E+02     0.3593665E+02
#      0.7259872E+02     0.3597758E+02
#      0.7260690E+02     0.3600573E+02
#      0.7262222E+02     0.3602877E+02
#      0.7262462E+02     0.3604274E+02
#      0.7261966E+02     0.3606458E+02
#      0.7258066E+02     0.3608716E+02
#      0.7256991E+02     0.3609482E+02
# ...
